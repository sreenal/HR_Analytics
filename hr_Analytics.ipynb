# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenal/HR_Analytics/blob/main/hr_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import VotingClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.svm import SVC 
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.ensemble import VotingClassifier 
from xgboost import XGBClassifier

# %%
df=pd.read_csv('/content/drive/MyDrive/Luminar_Projects/Project_2/hranalytics_train.csv')
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %% [markdown]
# Basic EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.9+ MB

# %%
df.describe().T
# Out:
#                         count          mean           std   min       25%  \
# employee_id           54808.0  39195.830627  22586.581449   1.0  19669.75
# no_of_trainings       54808.0      1.253011      0.609264   1.0      1.00
# age                   54808.0     34.803915      7.660169  20.0     29.00
# previous_year_rating  50684.0      3.329256      1.259993   1.0      3.00
# length_of_service     54808.0      5.865512      4.265094   1.0      3.00
# KPIs_met >80%         54808.0      0.351974      0.477590   0.0      0.00
# awards_won?           54808.0      0.023172      0.150450   0.0      0.00
# avg_training_score    54808.0     63.386750     13.371559  39.0     51.00
# is_promoted           54808.0      0.085170      0.279137   0.0      0.00
#
#                           50%      75%      max
# employee_id           39225.5  58730.5  78298.0
# no_of_trainings           1.0      1.0     10.0
# age                      33.0     39.0     60.0
# previous_year_rating      3.0      4.0      5.0
# length_of_service         5.0      7.0     37.0
# KPIs_met >80%             0.0      1.0      1.0
# awards_won?               0.0      0.0      1.0
# avg_training_score       60.0     76.0     99.0
# is_promoted               0.0      0.0      1.0

# %%
df.shape
# Out:
# (54808, 14)

# %%
df.isna().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %% [markdown]
# Fixing Null Values

# %%
df['education'].unique()
# Out:
# array(["Master's & above", "Bachelor's", nan, 'Below Secondary'],
#       dtype=object)

# %%
df['education'].value_counts()
# Out:
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: education, dtype: int64

# %%
df['education'].fillna(df['education'].mode()[0],inplace=True)

# %%
df['previous_year_rating'].unique()
# Out:
# array([ 5.,  3.,  1.,  4., nan,  2.])

# %%
df['previous_year_rating'].value_counts()
# Out:
# 3.0    18618
# 5.0    11741
# 4.0     9877
# 1.0     6223
# 2.0     4225
# Name: previous_year_rating, dtype: int64

# %%
df['previous_year_rating'].fillna(df['previous_year_rating'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
df['previous_year_rating']=df['previous_year_rating'].astype(int)

# %% [markdown]
# Converting Strings into Interger

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             54808 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  54808 non-null  int64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: int64(9), object(5)
# memory usage: 5.9+ MB

# %%
le_dept=LabelEncoder()
le_reg=LabelEncoder()
le_edu=LabelEncoder()
le_gen=LabelEncoder()
le_rech=LabelEncoder()

# %%
df['department'] = le_dept.fit_transform(df['department'])
df['recruitment_channel'] = le_rech.fit_transform(df['recruitment_channel' ])
df['gender'] = le_gen.fit_transform(df['gender'])
df['education'] = le_edu.fit_transform(df['education'])
df['region'] = le_reg.fit_transform(df['region'])

# %% [markdown]
# Making Label Pickel Files

# %%
import joblib 
joblib.dump(le_dept,'/content/drive/MyDrive/Luminar_Projects/Project_2/le_dept.pkl')
joblib.dump(le_reg,'/content/drive/MyDrive/Luminar_Projects/Project_2/le_reg.pkl')
joblib.dump(le_edu,'/content/drive/MyDrive/Luminar_Projects/Project_2/le_edu.pkl')
joblib.dump(le_gen,'/content/drive/MyDrive/Luminar_Projects/Project_2/le_gen.pkl')
joblib.dump(le_rech,'/content/drive/MyDrive/Luminar_Projects/Project_2/le_rech.pkl')
# Out:
# ['/content/drive/MyDrive/Luminar_Projects/Project_2/le_rech.pkl']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  int64
#  2   region                54808 non-null  int64
#  3   education             54808 non-null  int64
#  4   gender                54808 non-null  int64
#  5   recruitment_channel   54808 non-null  int64
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  54808 non-null  int64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: int64(14)
# memory usage: 5.9 MB

# %% [markdown]
# Correlation Study of DataSet

# %%
df.corr()
# Out:
#                       employee_id  department    region  education    gender  \
# employee_id              1.000000   -0.005187 -0.003423   0.002124 -0.001542
# department              -0.005187    1.000000 -0.020592   0.043441 -0.030108
# region                  -0.003423   -0.020592  1.000000  -0.003815  0.019730
# education                0.002124    0.043441 -0.003815   1.000000 -0.032368
# gender                  -0.001542   -0.030108  0.019730  -0.032368  1.000000
# recruitment_channel      0.005960    0.004732 -0.000920  -0.003564  0.006567
# no_of_trainings         -0.005121    0.014152 -0.004590  -0.033469  0.084501
# age                      0.000437    0.079162 -0.088918   0.339966 -0.016293
# previous_year_rating     0.004209   -0.135561 -0.005977   0.027393 -0.024024
# length_of_service        0.001274    0.059060 -0.058939   0.233666 -0.019675
# KPIs_met >80%           -0.002501   -0.088209 -0.007664   0.012123 -0.037400
# awards_won?              0.008420   -0.002151  0.000307  -0.001409  0.002381
# avg_training_score      -0.000586   -0.251626  0.023572   0.032787 -0.024494
# is_promoted              0.001206    0.000130  0.008841   0.029257 -0.011109
# department              -0.005187    1.000000 -0.020592   0.043441 -0.030108
#
#                       recruitment_channel  no_of_trainings       age  \
# employee_id                      0.005960        -0.005121  0.000437
# department                       0.004732         0.014152  0.079162
# region                          -0.000920        -0.004590 -0.088918
# education                       -0.003564        -0.033469  0.339966
# gender                           0.006567         0.084501 -0.016293
# recruitment_channel              1.000000        -0.010405 -0.011400
# no_of_trainings                 -0.010405         1.000000 -0.081278
# age                             -0.011400        -0.081278  1.000000
# previous_year_rating             0.005731        -0.061564  0.026810
# length_of_service               -0.002887        -0.057275  0.657111
# KPIs_met >80%                   -0.000297        -0.045576 -0.025592
# awards_won?                     -0.005510        -0.007628 -0.008169
# avg_training_score              -0.002416         0.042517 -0.048380
# is_promoted                      0.002229        -0.024896 -0.017166
# department                       0.004732         0.014152  0.079162
#
#                       previous_year_rating  length_of_service  KPIs_met >80%  \
# employee_id                       0.004209           0.001274      -0.002501
# department                       -0.135561           0.059060      -0.088209
# region                           -0.005977          -0.058939      -0.007664
# education                         0.027393           0.233666       0.012123
# gender                           -0.024024          -0.019675      -0.037400
# recruitment_channel               0.005731          -0.002887      -0.000297
# no_of_trainings                  -0.061564          -0.057275      -0.045576
# age                               0.026810           0.657111      -0.025592
# previous_year_rating              1.000000           0.023504       0.337367
# length_of_service                 0.023504           1.000000      -0.077693
# KPIs_met >80%                     0.337367          -0.077693       1.000000
# awards_won?                       0.026587          -0.039927       0.097000
# avg_training_score                0.071926          -0.038122       0.078391
# is_promoted                       0.153230          -0.010670       0.221582
# department                       -0.135561           0.059060      -0.088209
#
#                       awards_won?  avg_training_score  is_promoted  \
# employee_id              0.008420           -0.000586     0.001206
# department              -0.002151           -0.251626     0.000130
# region                   0.000307            0.023572     0.008841
# education               -0.001409            0.032787     0.029257
# gender                   0.002381           -0.024494    -0.011109
# recruitment_channel     -0.005510           -0.002416     0.002229
# no_of_trainings         -0.007628            0.042517    -0.024896
# age                     -0.008169           -0.048380    -0.017166
# previous_year_rating     0.026587            0.071926     0.153230
# length_of_service       -0.039927           -0.038122    -0.010670
# KPIs_met >80%            0.097000            0.078391     0.221582
# awards_won?              1.000000            0.072138     0.195871
# avg_training_score       0.072138            1.000000     0.181147
# is_promoted              0.195871            0.181147     1.000000
# department              -0.002151           -0.251626     0.000130
#
#                       department
# employee_id             -0.005187
# department               1.000000
# region                  -0.020592
# education                0.043441
# gender                  -0.030108
# recruitment_channel      0.004732
# no_of_trainings          0.014152
# age                      0.079162
# previous_year_rating    -0.135561
# length_of_service        0.059060
# KPIs_met >80%           -0.088209
# awards_won?             -0.002151
# avg_training_score      -0.251626
# is_promoted              0.000130
# department               1.000000

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.corr(),annot=True,cmap="jet")
plt.title("Correlation plot-HeatMap")
plt.show()

# %%
df.corr()['is_promoted']
# Out:
# employee_id             0.001206
# department              0.000130
# region                  0.008841
# education               0.029257
# gender                 -0.011109
# recruitment_channel     0.002229
# no_of_trainings        -0.024896
# age                    -0.017166
# previous_year_rating    0.153230
# length_of_service      -0.010670
# KPIs_met >80%           0.221582
# awards_won?             0.195871
# avg_training_score      0.181147
# is_promoted             1.000000
# Name: is_promoted, dtype: float64

# %%
sns.countplot(x='is_promoted',data=df)
plt.show()

# %% [markdown]
# PairPlot Visualization of DataSet

# %%
sns.pairplot(df,hue="is_promoted")

# %%
df['is_promoted'].value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
sns.countplot(x='is_promoted',data=df)
plt.show()

# %% [markdown]
# Handling OutLiers

# %%
numericalColumns = df.select_dtypes(include=np.number).columns

# %%
descriateCols=[]
continuesCols=[]



for column in numericalColumns:
    if df[column].nunique()>20:
        continuesCols.append(column)
    else:
        descriateCols.append(column)

# %%
continuesCols
# Out:
# ['employee_id', 'region', 'age', 'length_of_service', 'avg_training_score']

# %%
descriateCols
# Out:
# ['department',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'previous_year_rating',
#  'KPIs_met >80%',
#  'awards_won?',
#  'is_promoted',
#  'department ']

# %% [markdown]
# Capping Outliers

# %%
for column in continuesCols:
    upper_lim=df[column].mean()+df[column].std() *3
    lower_lim=df[column].mean()-df[column].std() *3

    df.loc[(df[column] > upper_lim),column] = upper_lim
    df.loc[(df[column] < lower_lim),column] = lower_lim

# %% [markdown]
# Setting X and y value From Given Dataset

# %%
X=df.drop(['is_promoted'],axis=1)
y=df['is_promoted']

# %%
X.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'department '],
#       dtype='object')

# %% [markdown]
# Splitting  Given Data into Traning and Test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=42)

# %% [markdown]
# Scaling Down The Data Set Using Standardscaler

# %%
sc=StandardScaler()

# %%
X_train_sc=sc.fit_transform(X_train)
X_test_sc=sc.transform(X_test)

# %% [markdown]
# Generating Scaling Pickel

# %%
import joblib
joblib.dump(sc,'/content/drive/MyDrive/Luminar_Projects/Project_2/scale.pkl')
# Out:
# ['/content/drive/MyDrive/Luminar_Projects/Project_2/scale.pkl']

# %% [markdown]
# Fitting ML Algorithms

# %%
log = LogisticRegression() 
rnd = RandomForestClassifier(n_estimators=100) 
adaboost = AdaBoostClassifier() 
gBoost = GradientBoostingClassifier()

svc= SVC() 
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
nbc=GaussianNB()

voting = VotingClassifier( estimators=[('Logistic_Regression',log),('Decision_Tree_Classifier',dtc),('Random_Forest_Classifier',rnd), ('AdaBoost_Classifier',adaboost),('Gradient_Boosting_Classifier',gBoost),('SVC',svc)], voting='hard')

# %%
model=[log,rnd,adaboost,gBoost,svc,dtc,knn,nbc,voting]
for clf in model:
    clf.fit(X_train_sc,y_train)
    y_pred=clf.predict(X_test_sc)
    score=clf.score(X_train_sc,y_train)
    score1=clf.score(X_test_sc, y_test)
    mse=mean_squared_error(y_test,y_pred)
    print(f"Train Accuarcy for {clf.__class__.__name__} is {score}")
    print(f"Test Accuarcy for {clf.__class__.__name__} is {score1}")
    print(f"The RMSE value for {clf.__class__.__name__} is {mse}") 
    print("="*30)
# Out:
# Train Accuarcy for LogisticRegression is 0.9157158029465429
# Test Accuarcy for LogisticRegression is 0.920495383424559
# The RMSE value for LogisticRegression is 0.07950461657544093
# ==============================
# Train Accuarcy for RandomForestClassifier is 1.0
# Test Accuarcy for RandomForestClassifier is 0.9418366782772157
# The RMSE value for RandomForestClassifier is 0.05816332172278432
# ==============================
# Train Accuarcy for AdaBoostClassifier is 0.9214890662019009
# Test Accuarcy for AdaBoostClassifier is 0.9278487311328578
# The RMSE value for AdaBoostClassifier is 0.07215126886714214
# ==============================
# Train Accuarcy for GradientBoostingClassifier is 0.93616731570491
# Test Accuarcy for GradientBoostingClassifier is 0.9400121634322994
# The RMSE value for GradientBoostingClassifier is 0.059987836567700556
# ==============================
# Train Accuarcy for SVC is 0.9226055935295879
# Test Accuarcy for SVC is 0.9258030629734063
# The RMSE value for SVC is 0.07419693702659369
# ==============================
# Train Accuarcy for DecisionTreeClassifier is 1.0
# Test Accuarcy for DecisionTreeClassifier is 0.8951180405816332
# The RMSE value for DecisionTreeClassifier is 0.10488195941836678
# ==============================
# Train Accuarcy for KNeighborsClassifier is 0.9278886740557174
# Test Accuarcy for KNeighborsClassifier is 0.9168463537347266
# The RMSE value for KNeighborsClassifier is 0.0831536462652734
# ==============================
# Train Accuarcy for GaussianNB is 0.9114130878788704
# Test Accuarcy for GaussianNB is 0.9155747221761487
# The RMSE value for GaussianNB is 0.08442527782385138
# ==============================
# Train Accuarcy for VotingClassifier is 0.9287601100187903
# Test Accuarcy for VotingClassifier is 0.9306684358931829
# The RMSE value for VotingClassifier is 0.06933156410681705
# ==============================

# %% [markdown]
# HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
lr_clf = LogisticRegression()
df_clf= DecisionTreeClassifier()
rf_clf= RandomForestClassifier()
adboost_clf= AdaBoostClassifier()
grad_clf=GradientBoostingClassifier()
svc_clf=SVC()
xgb_clf=XGBClassifier()
knn_clf=KNeighborsClassifier()

# %%
clf_list=[lr_clf,df_clf,rf_clf,adboost_clf,grad_clf,svc_clf,xgb_clf,knn_clf]

# %%
grid_params_lr= [{'penalty':['l1','l2'],'solver':['saga']}]

grid_params_df =[{'criterion':["gini","entropy"], 'splitter':['best','random'],'max_depth':[3,4,5],'min_samples_split':[2,3,4],'max_features':["auto","sqrt","log2"]}]

grid_params_rf=[{'n_estimators': [4, 6, 9], 'max_features': ['log2', 'sqrt','auto'], 'criterion': ['entropy', 'gini'],'max_depth': [2, 3, 5, 10]}]

grid_params_adboost=[{'n_estimators':[10,50,250,1000],'learning_rate':[0.01,0.1],}]

grid_params_grad=[{'loss':['deviance', 'exponential'],'learning_rate':[1,7,9],'criterion':['friedman_mse','squared_error']}]
grid_params_svc=[{'kernel':['linear','poly','rbf'],'degree':[3,4,5]}]
grid_params_xgb=[{'booster':['gbtree', 'gblinear'],'nthread':[10,15,25]}]
grid_params_knn=[{'n_neighbors':[5,7,9,11],'algorithm':['ball_tree','kd_tree','brute'],'leaf_size':[30,50,100]}]

# %%
clf_params=[grid_params_lr,grid_params_df,grid_params_rf,grid_params_adboost,grid_params_grad,grid_params_svc,grid_params_xgb,grid_params_knn]

# %%
for clf,clf_param in zip(clf_list,clf_params):
  print(f"The Classifier is {clf} and its hyper params are {clf_param}")

  grid_clf = GridSearchCV(estimator=clf,param_grid=clf_param,scoring="accuracy",cv=10)
  grid_clf.fit(X_train_sc,y_train)
  
  print(f"The Train accuracy for the {clf} is {grid_clf.score(X_train_sc,y_train)}")
  print(f"The Test accuracy for the {clf} is {grid_clf.score(X_test_sc,y_test)}")
  print(f"The Best Parameters for the {clf} is {grid_clf.best_params_}")
  print("====================\n")
# Out:
# The Classifier is LogisticRegression() and its hyper params are [{'penalty': ['l1', 'l2'], 'solver': ['saga']}]
# The Train accuracy for the LogisticRegression() is 0.9157158029465429
# The Test accuracy for the LogisticRegression() is 0.9205506717531929
# The Best Parameters for the LogisticRegression() is {'penalty': 'l1', 'solver': 'saga'}
# ====================
#
# The Classifier is DecisionTreeClassifier() and its hyper params are [{'criterion': ['gini', 'entropy'], 'splitter': ['best', 'random'], 'max_depth': [3, 4, 5], 'min_samples_split': [2, 3, 4], 'max_features': ['auto', 'sqrt', 'log2']}]
# The Train accuracy for the DecisionTreeClassifier() is 0.9220881784265135
# The Test accuracy for the DecisionTreeClassifier() is 0.9282357494332947
# The Best Parameters for the DecisionTreeClassifier() is {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 3, 'splitter': 'best'}
# ====================
#
# The Classifier is RandomForestClassifier() and its hyper params are [{'n_estimators': [4, 6, 9], 'max_features': ['log2', 'sqrt', 'auto'], 'criterion': ['entropy', 'gini'], 'max_depth': [2, 3, 5, 10]}]
# The Train accuracy for the RandomForestClassifier() is 0.9326543394787724
# The Test accuracy for the RandomForestClassifier() is 0.9327693923812683
# The Best Parameters for the RandomForestClassifier() is {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 6}
# ====================
#
# The Classifier is AdaBoostClassifier() and its hyper params are [{'n_estimators': [10, 50, 250, 1000], 'learning_rate': [0.01, 0.1]}]
# The Train accuracy for the AdaBoostClassifier() is 0.9220337136788214
# The Test accuracy for the AdaBoostClassifier() is 0.9279040194614917
# The Best Parameters for the AdaBoostClassifier() is {'learning_rate': 0.1, 'n_estimators': 1000}
# ====================
#
# The Classifier is GradientBoostingClassifier() and its hyper params are [{'loss': ['deviance', 'exponential'], 'learning_rate': [1, 7, 9], 'criterion': ['friedman_mse', 'squared_error']}]
# The Train accuracy for the GradientBoostingClassifier() is 0.9424307616894965
# The Test accuracy for the GradientBoostingClassifier() is 0.9411732183336098
# The Best Parameters for the GradientBoostingClassifier() is {'criterion': 'friedman_mse', 'learning_rate': 1, 'loss': 'exponential'}
# ====================
#
# The Classifier is SVC() and its hyper params are [{'kernel': ['linear', 'poly', 'rbf'], 'degree': [3, 4, 5]}]
# The Train accuracy for the SVC() is 0.9266087524849541
# The Test accuracy for the SVC() is 0.9253054680157019
# The Best Parameters for the SVC() is {'degree': 4, 'kernel': 'poly'}
# ====================
#
# The Classifier is XGBClassifier() and its hyper params are [{'booster': ['gbtree', 'gblinear'], 'nthread': [10, 15, 25]}]
# The Train accuracy for the XGBClassifier() is 0.9339342610495357
# The Test accuracy for the XGBClassifier() is 0.938242936916017
# The Best Parameters for the XGBClassifier() is {'booster': 'gbtree', 'nthread': 10}
# ====================
#
# The Classifier is KNeighborsClassifier() and its hyper params are [{'n_neighbors': [5, 7, 9, 11], 'algorithm': ['ball_tree', 'kd_tree', 'brute'], 'leaf_size': [30, 50, 100]}]
# The Train accuracy for the KNeighborsClassifier() is 0.9202363770049835
# The Test accuracy for the KNeighborsClassifier() is 0.9224857632553768
# The Best Parameters for the KNeighborsClassifier() is {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 11}
# ====================

# %% [markdown]
# Fitting Best Model

# %%
svc=SVC(degree= 3, kernel= 'linear',probability=True)
svc.fit(X_train_sc,y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %% [markdown]
# Generating Model Pickel

# %%
import joblib 
joblib.dump(svc,'/content/drive/MyDrive/Luminar_Projects/Project_2/model.pkl')
# Out:
# ['/content/drive/MyDrive/Luminar_Projects/Project_2/model.pkl']
